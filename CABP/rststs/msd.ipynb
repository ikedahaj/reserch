# %%
#第4回自主課題 (1)
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.cm as cm  # colormap
import numpy as np
import math
plt.rcParams["text.usetex"] =True 
fig = plt.figure(figsize=(12,12))
d=100.0
tau=7.111
ax1 = fig.add_subplot(111)

# t,msd,msdg= np.loadtxt(r"C:/Users/ikedah/Documents/sotukenn/workspace/manyaoup/tau100.000T1.000/msd_WCA9100dt100.000T1.000.dat", comments='#', unpack=True)
# plt.plot(t,msd, "o" ,markersize=1,color="r",label=r"msd")
# plt.plot(t,msdg, "x" ,markersize=2,color=cm.jet(0.4),label=r"-g")
t,msd,msdg= np.loadtxt(r"C:\Users\ikedah\Documents\sotukenn\workspace\manyaoup\pe80fai1.2\msd_WCA3100dt7.111T100.000.dat", comments='#', unpack=True)
plt.plot(t,msd, "o" ,markersize=5,color="r",label=r"msd")
plt.plot(t,msdg, "x" ,markersize=10,color=cm.jet(0.4),label=r"-g")
# t,msd= np.loadtxt(r"C:/Users/ikedah/Documents/sotukenn/workspace/manyaoup/msd_ljdt100.000T1.000.dat", comments='#', unpack=True)

# plt.plot(t,msd, "x" ,markersize=30,color=cm.jet(0.6),label=r"calcoo")
# plt.plot(t,msdg, "o" ,markersize=1,color=cm.jet(0.8),label=r"-g")
#t,msd,msdg= np.loadtxt(r"C:/Users/ikedah/Documents/sotukenn/workspace/manyaoup/WCAT1.000_tau100.000/msd_WCA2100dt100.000T1.000.dat", comments='#', unpack=True)

#plt.plot(t,msd, "x" ,markersize=1,color=cm.jet(1),label=r"calcoo")
#plt.plot(t,msdg, "o" ,markersize=1,color=cm.jet(2),label=r"-g")
#t2,msd2= np.loadtxt(r"C:/Users/ikedah/Documents/aoup_yann_tau100_D1_fai0.88.txt", comments='#', unpack=True)
#plt.plot(t2,msd2, "x" ,markersize=10,color="r",label=r"$yann$")
t2,msd2= np.loadtxt(r"C:/Users/ikedah/Documents/takakura_nama.txt", comments='#', unpack=True)
plt.plot(t2,msd2, "-x" ,markersize=5,color="g",label=r"takakura")
t2,msd2= np.loadtxt(r"C:/Users/ikedah/Documents/takakura_yoko.txt", comments='#', unpack=True)
plt.plot(t2,msd2, "-x" ,markersize=5,color="g",label=r"takakura")


t= np.linspace(0.00001, 1000, 1000) 
f= 2.*2.*d*(t+tau*(np.exp(-t/tau)-1.))
#plt.plot(t,f, "--",markersize=3,linewidth = 3.0, color="k", label=r"$T^*=pou$ theory")
tau=100
d=1
f2= 2.*2.*d*(t+tau*(np.exp(-t/tau)-1.))
plt.plot(t,f2, "--",markersize=3,linewidth = 3.0, color="b", label=r"$T^*=pou$ y")
    
plt.xscale('log')
plt.yscale('log')
# plt.xlim(0.01,60)
#plt.ylim(0.0001,10000)
plt.tick_params(which='major',width = 1, length = 10)
plt.tick_params(which='minor',width = 1, length = 5)

#plt.grid(which = "both", axis="x")
ax1.spines['top'].set_linewidth(3)
ax1.spines['bottom'].set_linewidth(3)
ax1.spines['left'].set_linewidth(3)
ax1.spines['right'].set_linewidth(3)
plt.xlabel(r"$t/t_0$",color='k', size=30)
plt.ylabel(r"$\langle \Delta \mathbf{r}(t)^2\rangle/a^2$",color='k', size=30)
plt.xticks(color='k', size=30)
plt.yticks(color='k', size=30)

plt.legend(ncol=1, loc=4, borderaxespad=0, fontsize=20,frameon=False)
#################################
plt.subplots_adjust(wspace=0.5, hspace=0.25)






plt.savefig(r'C:/Users/ikedah/Documents/sotukenn/workspace/aaouptakakura.png')
#plt.savefig(r'C:/Users/ikedah/Downloads/2022-simulation-training-main/2022-simulation-training-main/report/ene.pdf')
plt.show()

# %%
#第4回自主課題 (1)
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.cm as cm  # colormap
import numpy as np
import math
plt.rcParams["text.usetex"] =False 
fig = plt.figure(figsize=(12,12))
d=100.0
tau=7.111
ax1 = fig.add_subplot(111)

# t,msd,msdg= np.loadtxt(r"C:/Users/ikedah/Documents/sotukenn/workspace/manyaoup/tau0.010_L100.000/msd_WCA8100dt0.010T1.000.dat", comments='#', unpack=True)
# plt.plot(t,msd, "o" ,markersize=5,color="r",label=r"$/tau =2$")
# plt.plot(t,msdg, "x" ,markersize=10,color=cm.jet(0.4),label=r"$T^222$")
t,msd,msd2= np.loadtxt("/Users/ikedahajime/GitHub/reserch-1/CABP/rststs/stwr80lo0.20tau10.000m0.000v01.0/msd_lo0.195_tau10.000_m0.000.dat", comments='#', unpack=True)
plt.plot(t,msd, "o" ,markersize=5,color="r",label=r"run")
plt.plot(t,msd2, "x" ,markersize=5,color=cm.jet(0.4),label=r"$T^222$")
t,msd,msd2= np.loadtxt("/Users/ikedahajime/GitHub/reserch-1/CABP/rststs/stwr80lo0.20tau10.000m0.000v01.0/msd2_lo0.195_tau10.000_m0.000.dat", comments='#', unpack=True)
plt.plot(t,msd, "+" ,markersize=5,color="g",label=r"run")#plt.plot(t,msdg, "x" ,markersize=50,color=cm.jet(1),label=r"$T^222$")

tau=0.01
d=1
t= np.linspace(0.0001, 10, 1000) 
f= 2.*2.*d*(t+tau*(np.exp(-t/tau)-1.))
# plt.plot(t,f, "--",markersize=3,linewidth = 3.0, color="k", label=r" theory")
#tau=100
#d=100
#f2= 2.*2.*d*(t+tau*(np.exp(-t/tau)-1.))
#plt.plot(t,f2, "--",markersize=3,linewidth = 3.0, color="b", label=r"$T^*=pou$ y")
    
plt.xscale('log')
plt.yscale('log')
#plt.xlim(0.01,60)
#plt.ylim(0.0001,10000)
plt.tick_params(which='major',width = 1, length = 10)
plt.tick_params(which='minor',width = 1, length = 5)
ax1.spines['top'].set_linewidth(3)
ax1.spines['bottom'].set_linewidth(3)
ax1.spines['left'].set_linewidth(3)
ax1.spines['right'].set_linewidth(3)
plt.xlabel(r"$t/t_0$",color='k', size=30)
plt.ylabel(r"$\langle \Delta \mathbf{r}(t)^2\rangle/a^2$",color='k', size=30)
plt.xticks(color='k', size=30)
plt.yticks(color='k', size=30)

plt.legend(ncol=1, loc=4, borderaxespad=0, fontsize=20,frameon=False)
#################################
plt.subplots_adjust(wspace=0.5, hspace=0.25)






# plt.savefig(r'C:/Users/ikedah/Documents/sotukenn/workspace/yann.png')
#plt.savefig(r'C:/Users/ikedah/Downloads/2022-simulation-training-main/2022-simulation-training-main/report/ene.pdf')
plt.show()

# %%
#第4回自主課題 (1)
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.cm as cm  # colormap
import numpy as np
import math
plt.rcParams["text.usetex"] =True 
fig = plt.figure(figsize=(12,12))
d=1
tau=1
R=1
k=0.
mgn=0.1
ax1 = fig.add_subplot(111)
moji="kari"
t,msd= np.loadtxt("C:/Users/ikedah/Documents/sotukenn/workspace/hansyaenn/{}tau{:.3f}m{:.3f}/msd_R{:.3f}_tau{:.3f}_k{:.3f}_m{:.3f}.dat".format(moji,tau,mgn,R,tau,k,mgn), comments='#', unpack=True)
plt.plot(t,msd, "o" ,markersize=1,color="r",label=r"msd")


 
f= 2.*2.*d*(t+tau*(np.exp(-t/tau)-1.))
plt.plot(t,f, "--",markersize=3,linewidth = 3.0, color="k", label=r"non-interaction theory")
#tau=100
#d=100
#f2= 2.*2.*d*(t+tau*(np.exp(-t/tau)-1.))
#plt.plot(t,f2, "--",markersize=3,linewidth = 3.0, color="b", label=r"$T^*=pou$ y")
    
plt.xscale('log')
plt.yscale('log')
#plt.xlim(0.01,60)
#plt.ylim(0.0001,10000)
plt.tick_params(which='major',width = 1, length = 10)
plt.tick_params(which='minor',width = 1, length = 5)
ax1.spines['top'].set_linewidth(3)
ax1.spines['bottom'].set_linewidth(3)
ax1.spines['left'].set_linewidth(3)
ax1.spines['right'].set_linewidth(3)
plt.xlabel(r"$t/t_0$",color='k', size=30)
plt.ylabel(r"$\langle \Delta \mathbf{r}(t)^2\rangle/a^2$",color='k', size=30)
plt.xticks(color='k', size=30)
plt.yticks(color='k', size=30)

plt.legend(ncol=1, loc=4, borderaxespad=0, fontsize=20,frameon=False)
#################################
plt.subplots_adjust(wspace=0.5, hspace=0.25)






plt.savefig('C:/Users/ikedah/Documents/sotukenn/workspace/hansyaenn/msdtau{}k{}m{}R{}.png'.format(tau,k,mgn,R))
#plt.savefig(r'C:/Users/ikedah/Downloads/2022-simulation-training-main/2022-simulation-training-main/report/ene.pdf')
plt.show()

# %%
#第4回自主課題 (1)
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.cm as cm  # colormap
import numpy as np
import math
plt.rcParams["text.usetex"] =True 
fig = plt.figure(figsize=(12,12))


ax1 = fig.add_subplot(111)

def plotmsd(moji,tau,v0,mgn,R,i):
    t,msd= np.loadtxt("C:/Users/ikedah/Documents/sotukenn/workspace/refwca/{}R{:.1f}v0{:.1f}tau{:.3f}m{:.3f}/msd_R{:.3f}_tau{:.3f}_m{:.3f}.dat".format(moji,R,v0,tau,mgn,R,tau,mgn), comments='#', unpack=True)
    plt.plot(t,msd, "-" ,markersize=5,color=cm.jet(i),label="tau{},mg{},R{}".format(tau,mgn,R))
    
plt.xscale('log')
plt.yscale('log')
#plt.xlim(0.01,60)
#plt.ylim(0.0001,10000)
plt.tick_params(which='major',width = 1, length = 10)
plt.tick_params(which='minor',width = 1, length = 5)
ax1.spines['top'].set_linewidth(3)
ax1.spines['bottom'].set_linewidth(3)
ax1.spines['left'].set_linewidth(3)
ax1.spines['right'].set_linewidth(3)
plt.xlabel(r"$t/t_0$",color='k', size=30)
plt.ylabel(r"$\langle \Delta \mathbf{r}(t)^2\rangle/a^2$",color='k', size=30)
plt.xticks(color='k', size=30)
plt.yticks(color='k', size=30)


#################################
plt.subplots_adjust(wspace=0.5, hspace=0.25)
moji="stwne4"
tau=10
mgn=0
R=28.868#22.361
tau=10
v0=1
i=0
plotmsd(moji,tau,v0,mgn,R,i)
# plotmsd(moji,tau,v0,0.01,R,2/5)
plotmsd(moji,tau,v0,0.1,R,3/5)
plotmsd(moji,tau,v0,1,R,4/5)
plotmsd(moji,tau,v0,2,R,5/5)
plt.legend(ncol=1, loc=4, borderaxespad=0, fontsize=20,frameon=False)
x=np.linspace(0.01,tau*2,100)
x2=np.linspace(tau,1000,500)
plt.plot(x,x*x,"--",color="b")
plt.plot(x2,x2,"--",color="g")

plt.savefig('C:/Users/ikedah/Documents/sotukenn/workspace/refwca/msdtau{}m{}R{}.png'.format(tau,mgn,R))
#plt.savefig(r'C:/Users/ikedah/Downloads/2022-simulation-training-main/2022-simulation-training-main/report/ene.pdf')
plt.show()
