# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
#図の解像度が上がる
#%config InlineBackend.figure_format = 'retina'
import numpy as np
import matplotlib.cm as cm
#Tex フォント
#plt.rcParams["text.usetex"] =True 
#図全体のサイズやアスペクト比を変える
fig = plt.figure(figsize=(8,8))
#複数の図を並べる時ここを変える

 ###########################

ax1 = fig.add_subplot(1,1,1)
#各自ファイルのパスを変えること
x= np.linspace(0.01, 100, 1000)  #ログをとるとき
dim=2.
#x=np.linspace(0,10,50)　#リニアなとき
R=3
moji="wallD"
D=1
tau=0.1
k=0
mg=0
yes=10000#filenum_max,自動にしたいときは0;
yyes=00#tmin,自動でも方っておいて良い
# plt.xlim(-R,R)
# plt.ylim(-R,R)
t2,x,y,lz=np.loadtxt("C:\\Users\\ikedah\\Documents\\sotukenn\\workspace\\hansyaenn\\{}{:.1f}tau{:.3f}m{:.3f}\\coordtui_R{:.3f}_tau{:.3f}_k{:.3f}_m{:.3f}.dat".format(moji,D,tau,mg,R,tau,k,mg),comments='#', unpack=True)
# 
mmax=np.amax(lz)
mmin=np.amin(lz)
vminmax=max(mmax,mmin)
if yes==0:

    pltmax=len(x)-1
    pltmin=0
else:
    pltmax=yes
    pltmin=yyes
tmax=pltmax-pltmin
plt.scatter(x[pltmin:pltmax],y[pltmin:pltmax],s=10,c=lz[pltmin:pltmax],cmap="jet",vmax=vminmax,vmin=-vminmax,linestyle="-")
plt.plot(x[pltmin:pltmin+50],y[pltmin:pltmin+50],"-",color="k")
C=plt.colorbar(shrink=0.6) # shirink:  controlling the size of color bar: 1.0 is maximum
C.set_label("lz", fontsize=20) # color bar label
def circleplot():
    t = np.linspace(0,np.pi*2,100)
    x = R * np.cos(t)
    y = R * np.sin(t)
    plt.plot(x,y,"-",color="k",markersize=20)
circleplot()
mtau=r"$\tau$"
mmgn=r"$\omega$"
mrangle=r"$\rangle$"
i=0

print(t2[-1])
plt.title("{}={},{}={},k={},D={},tmin={}tmax={}".format(mtau,tau,mmgn,mg,k,D,pltmin/10,pltmax/10))
###Drawing a line ######
t = np.linspace(0,1,50)
# x = 5 * np.cos(t)
# y = 5 * np.sin(t)
x=1024/np.pi+0*t
# plt.plot(x,y,"-",color="k",markersize=20)
# plt.plot(t, x, "--",markersize=3,linewidth = 2.0, color="k",label=r"uniform")
#########
# t,x,y,vx,vy,lz=np.loadtxt(r"C:/Users/ikedah/Documents/sotukenn/workspace/hansyaenn/tyouwaenn/tyouwaenn_R5.000_tau10.000_k0.000_m10.000_t0.dat",comments='#',unpack=True)
# plt.scatter(x,y,s=50,c=lz,cmap='jet')
# plt.plot(x,y,markersize=5,color=cm.jet(lz))
#図の書式設定
plt.tick_params(which='major',width = 1, length = 10)
plt.tick_params(which='minor',width = 1, length = 5)
ax1.spines['top'].set_linewidth(3)
ax1.spines['bottom'].set_linewidth(3)
ax1.spines['left'].set_linewidth(3)
ax1.spines['right'].set_linewidth(3)
plt.xlabel(r"$x$",color='k', size=30)
plt.ylabel(r"$y$",color='k', size=30)
plt.xticks(color='k', size=20)
plt.yticks(color='k', size=20)
ax1.set_aspect('equal')
#図の凡例の有無や位置，サイズを調整
# plt.legend(ncol=1, loc=4, borderaxespad=0, fontsize=25,frameon=False)
# plt.colorbar()
#各グラフのアスペクト比を1:1にする
#################################
#図のマージン設定
plt.subplots_adjust(wspace=0.3, hspace=0.25)

#各自ファイルのパスを変えること．
plt.savefig('C:/Users/ikedah/Documents/sotukenn/workspace/hansyaenn/mapss/{}{}tau{}om{}0.png'.format(moji,D,tau,mg))
#plt.savefig(r'C:/Users/ikedah/Downloads/2022-simulation-training-main/2022-simulation-training-main/report1-2-0.1-2-10.pdf')
plt.show()
# Out:
# 100.0

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
#図の解像度が上がる
#%config InlineBackend.figure_format = 'retina'
import numpy as np
import matplotlib.cm as cm
#Tex フォント
#plt.rcParams["text.usetex"] =True 
#図全体のサイズやアスペクト比を変える
fig = plt.figure(figsize=(8,8))
#複数の図を並べる時ここを変える

 ###########################

ax1 = fig.add_subplot(1,1,1)
#各自ファイルのパスを変えること
x= np.linspace(0.01, 100, 1000)  #ログをとるとき
dim=2.
#x=np.linspace(0,10,50)　#リニアなとき
R=1
moji="wallbD"
v0=1
tau=100
k=0
Mg=1
D=tau*v0
mg=Mg*tau
yes=40000#filenum_max,自動にしたいときは0;
yyes=30000#tmin,自動でも方っておいて良い
# plt.xlim(-R,R)
# plt.ylim(-R,R)
t2,x,y,lz=np.loadtxt("C:\\Users\\ikedah\\Documents\\sotukenn\\workspace\\hannew\\{}{:.1f}tau{:.3f}m{:.3f}\\coordtui_R{:.3f}_tau{:.3f}_k{:.3f}_m{:.3f}.dat".format(moji,D,tau,mg,R,tau,k,mg),comments='#', unpack=True)
# 
lz/=np.sqrt(np.square(x)+np.square(y))
mmax=np.amax(lz)
mmin=np.amin(lz)
vminmax=max(mmax,mmin)
if yes==0:

    pltmax=len(x)-1
    pltmin=0
else:
    pltmax=yes
    pltmin=yyes
tmax=pltmax-pltmin
plt.scatter(x[pltmin:pltmax],y[pltmin:pltmax],s=10,c=lz[pltmin:pltmax],cmap="jet",vmax=vminmax,vmin=-vminmax,linestyle="-")
plt.plot(x[pltmin:pltmin+50],y[pltmin:pltmin+50],"-",color="k")
C=plt.colorbar(shrink=0.6) # shirink:  controlling the size of color bar: 1.0 is maximum
C.set_label(r"$v_{\theta}$", fontsize=20) # color bar label
def circleplot():
    t = np.linspace(0,np.pi*2,100)
    x = R * np.cos(t)
    y = R * np.sin(t)
    plt.plot(x,y,"-",color="k",markersize=20)
circleplot()
mtau=r"$\tau$"
mmgn=r"$\Omega$"
mrangle=r"$\rangle$"


print(t2[-1])
plt.title("{}={},{}={},k={},$v_0^2$={},tmin={}tmax={}".format(mtau,tau,mmgn,Mg,k,v0,pltmin/10,pltmax/10))
###Drawing a line ######

#図の書式設定
plt.tick_params(which='major',width = 1, length = 10)
plt.tick_params(which='minor',width = 1, length = 5)
ax1.spines['top'].set_linewidth(3)
ax1.spines['bottom'].set_linewidth(3)
ax1.spines['left'].set_linewidth(3)
ax1.spines['right'].set_linewidth(3)
plt.xlabel(r"$x$",color='k', size=30)
plt.ylabel(r"$y$",color='k', size=30)
plt.xticks(color='k', size=20)
plt.yticks(color='k', size=20)
ax1.set_aspect('equal')
#図の凡例の有無や位置，サイズを調整
# plt.legend(ncol=1, loc=4, borderaxespad=0, fontsize=25,frameon=False)
# plt.colorbar()
#各グラフのアスペクト比を1:1にする
#################################
#図のマージン設定
plt.subplots_adjust(wspace=0.3, hspace=0.25)

#各自ファイルのパスを変えること．
plt.savefig('C:/Users/ikedah/Documents/sotukenn/workspace/hansyaenn/mapss/{}{}tau{}om{}0.png'.format(moji,D,tau,mg))
#plt.savefig(r'C:/Users/ikedah/Downloads/2022-simulation-training-main/2022-simulation-training-main/report1-2-0.1-2-10.pdf')
plt.show()
# Out:
# 40100.0

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
#図の解像度が上がる
#%config InlineBackend.figure_format = 'retina'
import numpy as np
import matplotlib.cm as cm
#Tex フォント
#plt.rcParams["text.usetex"] =True 
#図全体のサイズやアスペクト比を変える
fig = plt.figure(figsize=(8,8))
#複数の図を並べる時ここを変える

 ###########################

ax1 = fig.add_subplot(1,1,1)
#各自ファイルのパスを変えること
# x= np.linspace(0.01, 100, 1000)  #ログをとるとき
dim=2.
#x=np.linspace(0,10,50)　#リニアなとき
R=1
moji="wallb_coorD"
D=100
tau=100
k=0
mg=100
yes=000#filenum_max,自動にしたいときは0;
yyes=000#tmin,自動でも方っておいて良い
# plt.xlim(-R,R)
# plt.ylim(-R,R)
t2,x,y,vx,vy,lz=np.loadtxt("C:\\Users\\ikedah\\Documents\\sotukenn\\workspace\\hannew\\{}{:.1f}tau{:.3f}m{:.3f}\\tyouwaenn_R{:.3f}_tau{:.3f}_k{:.3f}_m{:.3f}_t1.dat".format(moji,D,tau,mg,R,tau,k,mg),comments='#', unpack=True)
# 
lz/=np.sqrt(np.square(x)+np.square(y))
vminmax=np.amax(lz)



plt.scatter(x,y,s=10,c=lz,cmap="jet",vmax=vminmax,vmin=-vminmax,linestyle="-")
# plt.plot(x[pltmin:pltmin+50],y[pltmin:pltmin+50],"-",color="k")
C=plt.colorbar(shrink=0.6) # shirink:  controlling the size of color bar: 1.0 is maximum
C.set_label("lz", fontsize=20) # color bar label
def circleplot():
    t = np.linspace(0,np.pi*2,100)
    x = R * np.cos(t)
    y = R * np.sin(t)
    plt.plot(x,y,"-",color="k",markersize=20)
circleplot()
mtau=r"$\tau$"
mmgn=r"$\omega$"
mrangle=r"$\rangle$"
i=0

print(t2[-1])
plt.title("{}={},{}={},k={},D={}".format(mtau,tau,mmgn,mg,k,D))
###Drawing a line ######
t = np.linspace(0,1,50)
# x = 5 * np.cos(t)
# y = 5 * np.sin(t)
x=1024/np.pi+0*t
# plt.plot(x,y,"-",color="k",markersize=20)
# plt.plot(t, x, "--",markersize=3,linewidth = 2.0, color="k",label=r"uniform")
#########
# t,x,y,vx,vy,lz=np.loadtxt(r"C:/Users/ikedah/Documents/sotukenn/workspace/hansyaenn/tyouwaenn/tyouwaenn_R5.000_tau10.000_k0.000_m10.000_t0.dat",comments='#',unpack=True)
# plt.scatter(x,y,s=50,c=lz,cmap='jet')
# plt.plot(x,y,markersize=5,color=cm.jet(lz))
#図の書式設定
plt.tick_params(which='major',width = 1, length = 10)
plt.tick_params(which='minor',width = 1, length = 5)
ax1.spines['top'].set_linewidth(3)
ax1.spines['bottom'].set_linewidth(3)
ax1.spines['left'].set_linewidth(3)
ax1.spines['right'].set_linewidth(3)
plt.xlabel(r"$x$",color='k', size=30)
plt.ylabel(r"$y$",color='k', size=30)
plt.xticks(color='k', size=20)
plt.yticks(color='k', size=20)
ax1.set_aspect('equal')
#図の凡例の有無や位置，サイズを調整
# plt.legend(ncol=1, loc=4, borderaxespad=0, fontsize=25,frameon=False)
# plt.colorbar()
#各グラフのアスペクト比を1:1にする
#################################
#図のマージン設定
plt.subplots_adjust(wspace=0.3, hspace=0.25)

#各自ファイルのパスを変えること．
# plt.savefig('C:/Users/ikedah/Documents/sotukenn/workspace/hansyaenn/mapss/{}{}tau{}om{}.png'.format(moji,D,tau,mg))
#plt.savefig(r'C:/Users/ikedah/Downloads/2022-simulation-training-main/2022-simulation-training-main/report1-2-0.1-2-10.pdf')
plt.show()
# Out:
# 0.0001

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
#図の解像度が上がる
#%config InlineBackend.figure_format = 'retina'
import numpy as np
import matplotlib.cm as cm
#Tex フォント
#plt.rcParams["text.usetex"] =True 
#図全体のサイズやアスペクト比を変える
fig = plt.figure(figsize=(8,8))
#複数の図を並べる時ここを変える

 ###########################

ax1 = fig.add_subplot(1,1,1)
#各自ファイルのパスを変えること
x= np.linspace(0.01, 100, 1000)  #ログをとるとき
dim=2.
#x=np.linspace(0,10,50)　#リニアなとき
R=1
moji="freeD"
mmoji=1
D=00
tau=00
k=0.
mg=141.4213
do_omega=0#1奈良lzでなく角速度になる;
yes=000#filenum_max,自動にしたいときは0;
yyes=000#tmin,自動でも方っておいて良い
# plt.xlim(-R,R)
# plt.ylim(-R,R)
t2,x,y,lz,v=np.loadtxt("C:\\Users\\ikedah\\Documents\\sotukenn\\workspace\\gaoup_ref\\{}{:.1f}tau{:.3f}m{:.3f}\\coordtuii_R{:.3f}_tau{:.3f}_k{:.3f}_m{:.3f}.dat".format(moji,D,tau,mg,R,tau,k,mg),comments='#', unpack=True)
# 
if do_omega==1:
    r2=np.square(x)+np.square(y)
    lz=lz/r2
if yes==0:

    pltmax=len(x)-1
    pltmin=0
else:
    pltmax=yes
    pltmin=yyes
tmax=pltmax-pltmin
mmax=np.amax(lz[pltmin:pltmax])
mmin=np.amin(lz[pltmin:pltmax])
vminmax=max(mmax,-mmin)
plt.scatter(x[pltmin:pltmax],y[pltmin:pltmax],s=10,c=lz[pltmin:pltmax],cmap="jet",vmax=vminmax,vmin=-vminmax,linestyle="-")
plt.plot(x[pltmax-50:pltmax],y[pltmax-50:pltmax],"-",color="b")
# plt.plot(x[pltmin:pltmax],y[pltmin:pltmax],"-",color="k")
plt.plot(x[pltmin:pltmin+50],y[pltmin:pltmin+50],"-",color="k")
C=plt.colorbar(shrink=0.6) # shirink:  controlling the size of color bar: 1.0 is maximum
C.set_label(r"$lz$", fontsize=10)  # color bar label
def circleplot():
    t = np.linspace(0,np.pi*2,100)
    x = R * np.cos(t)
    y = R * np.sin(t)
    plt.plot(x,y,"-",color="k",markersize=20)
circleplot()
mtau=r"$\tau$"
mmgn=r"$\omega$"
mrangle=r"$\rangle$"
i=0

print(t2[-1])
plt.title("{}={},{}={},k={},D={},tmin={}tmax={}".format(mtau,tau,mmgn,mg,k,D,pltmin/10,pltmax/10))
###Drawing a line ######
t = np.linspace(0,1,50)
# x = 5 * np.cos(t)
# y = 5 * np.sin(t)
x=1024/np.pi+0*t
# plt.plot(x,y,"-",color="k",markersize=20)
# plt.plot(t, x, "--",markersize=3,linewidth = 2.0, color="k",label=r"uniform")
#########
# t,x,y,vx,vy,lz=np.loadtxt(r"C:/Users/ikedah/Documents/sotukenn/workspace/hansyaenn/tyouwaenn/tyouwaenn_R5.000_tau10.000_k0.000_m10.000_t0.dat",comments='#',unpack=True)
# plt.scatter(x,y,s=50,c=lz,cmap='jet')
# plt.plot(x,y,markersize=5,color=cm.jet(lz))
#図の書式設定
plt.tick_params(which='major',width = 1, length = 10)
plt.tick_params(which='minor',width = 1, length = 5)
ax1.spines['top'].set_linewidth(3)
ax1.spines['bottom'].set_linewidth(3)
ax1.spines['left'].set_linewidth(3)
ax1.spines['right'].set_linewidth(3)
plt.xlabel(r"$x$",color='k', size=10)
plt.ylabel(r"$y$",color='k', size=10)
plt.xticks(color='k', size=10)
plt.yticks(color='k', size=10)
ax1.set_aspect('equal')
#図の凡例の有無や位置，サイズを調整
# plt.legend(ncol=1, loc=4, borderaxespad=0, fontsize=25,frameon=False)
# plt.colorbar()
#各グラフのアスペクト比を1:1にする
#################################
#図のマージン設定
plt.subplots_adjust(wspace=0.3, hspace=0.25)

#各自ファイルのパスを変えること．
plt.savefig('C:/Users/ikedah/Documents/sotukenn/workspace/hansyaenn/mapss/{}{}tau{}om{}{}{}p.png'.format(moji,D,tau,mg,mmoji,do_omega))
#plt.savefig(r'C:/Users/ikedah/Downloads/2022-simulation-training-main/2022-simulation-training-main/report1-2-0.1-2-10.pdf')
plt.show()
# Out:
# 200.0

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
#図の解像度が上がる
#%config InlineBackend.figure_format = 'retina'
import numpy as np
import matplotlib.cm as cm
#Tex フォント
#plt.rcParams["text.usetex"] =True 
#図全体のサイズやアスペクト比を変える
fig = plt.figure(figsize=(8,8))
#複数の図を並べる時ここを変える

 ###########################

ax1 = fig.add_subplot(1,1,1)
#各自ファイルのパスを変えること
# x= np.linspace(0.01, 100, 1000)  #ログをとるとき
dim=2.
#x=np.linspace(0,10,50)　#リニアなとき
R=3
moji="wallre2D"
mmoji=1
D=100
tau=100
k=0
mg=0
do_omega=1#1奈良lzでなく角速度になる;
yes=0#filenum_max,自動にしたいときは0;
yyes=000#tmin,自動でも方っておいて良い
# plt.xlim(-R,R)
# plt.ylim(-R,R)
t2,x,y,lz,v=np.loadtxt("C:\\Users\\ikedah\\Documents\\sotukenn\\workspace\\gaoup_ref\\{}{:.1f}tau{:.3f}m{:.3f}\\coordtuii_R{:.3f}_tau{:.3f}_k{:.3f}_m{:.3f}.dat".format(moji,D,tau,mg,R,tau,k,mg),comments='#', unpack=True)
# t2,x,y,lz,v=np.loadtxt(r"C:\Users\ikedah\Documents\sotukenn\workspace\gaoup_ref\walltie2D0.0tau0.000m0.000\coordtuii_R3.000_tau100.000_k0.000_m0.000.dat",comments='#', unpack=True)
 
if do_omega==1:
    r2=np.square(x)+np.square(y)
    lz=lz/np.sqrt(r2)
if yes==0:

    pltmax=len(x)-1
    pltmin=0
else:
    pltmax=yes
    pltmin=yyes
tmax=pltmax-pltmin
mmax=np.amax(lz[pltmin:pltmax])
mmin=np.amin(lz[pltmin:pltmax])
vminmax=max(mmax,-mmin)
# plt.scatter(x[pltmin:pltmax],y[pltmin:pltmax],s=10,c=lz[pltmin:pltmax],cmap="jet",vmax=vminmax,vmin=-vminmax,linestyle="-")
# plt.plot(x[pltmax-50:pltmax],y[pltmax-50:pltmax],"-",color="b")
# plt.plot(x[pltmin:pltmax],y[pltmin:pltmax],"-",color="k")
plt.plot(x[pltmin:pltmin+50],y[pltmin:pltmin+50],"-",color="k")
C=plt.colorbar(shrink=0.6) # shirink:  controlling the size of color bar: 1.0 is maximum

C.set_label(r"$lz$", fontsize=10)  # color bar label
def circleplot():
    t = np.linspace(0,np.pi*2,100)
    x = R * np.cos(t)
    y = R * np.sin(t)
    plt.plot(x,y,"-",color="k",markersize=20)
circleplot()
mtau=r"$\tau$"
mmgn=r"$\omega$"
mrangle=r"$\rangle$"
i=0

print(t2[-1])
plt.title("{}={},{}={},k={},D={},tmin={}tmax={}".format(mtau,tau,mmgn,mg,k,D,pltmin/10,pltmax/10))
###Drawing a line ######
t = np.linspace(0,1,50)
# x = 5 * np.cos(t)
# y = 5 * np.sin(t)
x=1024/np.pi+0*t
# plt.plot(x,y,"-",color="k",markersize=20)
# plt.plot(t, x, "--",markersize=3,linewidth = 2.0, color="k",label=r"uniform")
#########
# t,x,y,vx,vy,lz=np.loadtxt(r"C:/Users/ikedah/Documents/sotukenn/workspace/hansyaenn/tyouwaenn/tyouwaenn_R5.000_tau10.000_k0.000_m10.000_t0.dat",comments='#',unpack=True)
# plt.scatter(x,y,s=50,c=lz,cmap='jet')
# plt.plot(x,y,markersize=5,color=cm.jet(lz))
#図の書式設定
plt.tick_params(which='major',width = 1, length = 10)
plt.tick_params(which='minor',width = 1, length = 5)
ax1.spines['top'].set_linewidth(3)
ax1.spines['bottom'].set_linewidth(3)
ax1.spines['left'].set_linewidth(3)
ax1.spines['right'].set_linewidth(3)
plt.xlabel(r"$x$",color='k', size=10)
plt.ylabel(r"$y$",color='k', size=10)
plt.xticks(color='k', size=10)
plt.yticks(color='k', size=10)
ax1.set_aspect('equal')
#図の凡例の有無や位置，サイズを調整
# plt.legend(ncol=1, loc=4, borderaxespad=0, fontsize=25,frameon=False)
# plt.colorbar()
#各グラフのアスペクト比を1:1にする
#################################
#図のマージン設定
plt.subplots_adjust(wspace=0.3, hspace=0.25)

#各自ファイルのパスを変えること．
plt.savefig('C:/Users/ikedah/Documents/sotukenn/workspace/hansyaenn/mapss/{}{}tau{}om{}{}{}p.png'.format(moji,D,tau,mg,mmoji,do_omega))
#plt.savefig(r'C:/Users/ikedah/Downloads/2022-simulation-training-main/2022-simulation-training-main/report1-2-0.1-2-10.pdf')
plt.show()
ax1 = fig.add_subplot(1,1,1)
plt.hist(v**2,bins=50)
plt.show()
print(np.mean(v**2))
# Out:
# 2000.0
# 1.8120536046351414

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
#図の解像度が上がる
#%config InlineBackend.figure_format = 'retina'
import numpy as np
import matplotlib.cm as cm
#Tex フォント
#plt.rcParams["text.usetex"] =True 
#図全体のサイズやアスペクト比を変える
fig = plt.figure(figsize=(8,8))
#複数の図を並べる時ここを変える

 ###########################

ax1 = fig.add_subplot(1,1,1)
#各自ファイルのパスを変えること
# x= np.linspace(0.01, 100, 1000)  #ログをとるとき
dim=2.
#x=np.linspace(0,10,50)　#リニアなとき
R=70.711
moji="wallparD"
mmoji=1
D=100
tau=100
k=0
mg=1
do_omega=0#1奈良lzでなく角速度になる;
yes=000#filenum_max,自動にしたいときは0;
yyes=000#tmin,自動でも方っておいて良い
plt.xlim(-R,R)
plt.ylim(-R,R)
t2,x,y,lz=np.loadtxt("C:\\Users\\ikedah\\Documents\\sotukenn\\workspace\\gaoup_ref\\{}{:.1f}tau{:.3f}m{:.3f}\\coordtuii_R{:.3f}_tau{:.3f}_k{:.3f}_m{:.3f}.dat".format(moji,D,tau,mg,R,tau,k,mg),comments='#', unpack=True)
# t2,x,y,lz,v=np.loadtxt(r"C:\Users\ikedah\Documents\sotukenn\workspace\gaoup_ref\wallD100.0tau100.000m100.000\coordtuii_R1.000_tau100.000_k0.000_m100.000.dat",comments='#', unpack=True)
if do_omega==1:
    r2=np.square(x)+np.square(y)
    lz=lz/np.sqrt(r2)
if yes==0:

    pltmax=len(x)-1
    pltmin=0
else:
    pltmax=yes
    pltmin=yyes
tmax=pltmax-pltmin
mmax=np.amax(lz[pltmin:pltmax])
mmin=np.amin(lz[pltmin:pltmax])
vminmax=max(mmax,-mmin)
plt.scatter(x[pltmin:pltmax],y[pltmin:pltmax],s=10,c=lz[pltmin:pltmax],cmap="jet",vmax=vminmax,vmin=-vminmax,linestyle="-")
plt.plot(x[pltmax-tau:pltmax],y[pltmax-tau:pltmax],"-",color="b")
# plt.plot(x,y,"-",color="k")
# plt.plot(x[pltmin:pltmin+50],y[pltmin:pltmin+50],"-",color="k")
C=plt.colorbar(shrink=0.6) # shirink:  controlling the size of color bar: 1.0 is maximum

C.set_label(r"$\omega$", fontsize=10)  # color bar label
def circleplot():
    t = np.linspace(0,np.pi*2,1000)
    x = R * np.cos(t)
    y = R * np.sin(t)
    plt.plot(x,y,"-",color="k",markersize=20)
circleplot()
mtau=r"$\tau$"
mmgn=r"$\omega$"
mrangle=r"$\rangle$"
i=0

print(t2[-1])
# plt.title("{}={},{}={},k={},D={},tmin={}tmax={}".format(mtau,tau,mmgn,mg,k,D,pltmin/10,pltmax/10))
###Drawing a line ######
t = np.linspace(0,1,50)
# x = 5 * np.cos(t)
# y = 5 * np.sin(t)
x=1024/np.pi+0*t
# plt.plot(x,y,"-",color="k",markersize=20)
# plt.plot(t, x, "--",markersize=3,linewidth = 2.0, color="k",label=r"uniform")
#########
# t,x,y,vx,vy,lz=np.loadtxt(r"C:/Users/ikedah/Documents/sotukenn/workspace/hansyaenn/tyouwaenn/tyouwaenn_R5.000_tau10.000_k0.000_m10.000_t0.dat",comments='#',unpack=True)
# plt.scatter(x,y,s=50,c=lz,cmap='jet')
# plt.plot(x,y,markersize=5,color=cm.jet(lz))
#図の書式設定
plt.tick_params(which='major',width = 1, length = 10)
plt.tick_params(which='minor',width = 1, length = 5)
ax1.spines['top'].set_linewidth(3)
ax1.spines['bottom'].set_linewidth(3)
ax1.spines['left'].set_linewidth(3)
ax1.spines['right'].set_linewidth(3)
plt.xlabel(r"$x$",color='k', size=10)
plt.ylabel(r"$y$",color='k', size=10)
plt.xticks(color='k', size=10)
plt.yticks(color='k', size=10)
ax1.set_aspect('equal')
#図の凡例の有無や位置，サイズを調整
# plt.legend(ncol=1, loc=4, borderaxespad=0, fontsize=25,frameon=False)
# plt.colorbar()
#各グラフのアスペクト比を1:1にする
#################################
#図のマージン設定
plt.subplots_adjust(wspace=0.3, hspace=0.25)

#各自ファイルのパスを変えること．
plt.savefig('C:/Users/ikedah/Documents/sotukenn/workspace/hansyaenn/mapss/{}{}tau{}om{}{}{}poo.png'.format(moji,D,tau,mg,mmoji,do_omega))
#plt.savefig(r'C:/Users/ikedah/Downloads/2022-simulation-training-main/2022-simulation-training-main/report1-2-0.1-2-10.pdf')
plt.show()
# Out:
# 500.0

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
#図の解像度が上がる
#%config InlineBackend.figure_format = 'retina'
import numpy as np
import matplotlib.cm as cm
import matplotlib.colors as co
#Tex フォント
#plt.rcParams["text.usetex"] =True 
#図全体のサイズやアスペクト比を変える
fig = plt.figure(figsize=(12,11))
#複数の図を並べる時ここを変える

 ###########################

ax1 = fig.add_subplot(1,1,1)
#各自ファイルのパスを変えること
x= np.linspace(0.01, 100, 1000)  #ログをとるとき
dim=2.
#x=np.linspace(0,10,50)　#リニアなとき
R=160
moji="wall2"
tau=10
k=0
mg=10
vminmax=2
t2,x,y,vx,vy,lz=np.loadtxt(r"C:\Users\ikedah\Documents\sotukenn\workspace\atcoder\tyouwaenn_R160.000_tau10.000_k0.000_m0.000_t0.dat",comments='#', unpack=True)
colomp=co.Normalize(-vminmax,vminmax,lz)
lz=lz/np.sqrt(np.square(x)+np.square(y))
# plt.plot(x,y,"o")
def circleplot():
    t = np.linspace(0,np.pi*2,100)
    x = R * np.cos(t)
    y = R * np.sin(t)
    plt.plot(x,y,"-",color="k",markersize=20)
# circleplot()
mtau=r"$\tau$"
mmgn=r"$\omega$"
mrangle=r"$\rangle$"
i=0
D=1
plt.title("{}={},{}={}".format(mtau,tau,mmgn,mg))
###Drawing a line ######
t = np.linspace(0,1,50)
# x = 5 * np.cos(t)
# y = 5 * np.sin(t)
# x=1024/np.pi+0*t
# plt.plot(x,y,"-",color="k",markersize=20)
# plt.plot(t, x, "--",markersize=3,linewidth = 2.0, color="k",label=r"uniform")
#########
# t,x,y,vx,vy,lz=np.loadtxt(r"C:/Users/ikedah/Documents/sotukenn/workspace/hansyaenn/tyouwaenn/tyouwaenn_R5.000_tau10.000_k0.000_m10.000_t0.dat",comments='#',unpack=True)
plt.scatter(x[0],y[0],s=50,c=lz[0],cmap='jet')
plt.clim(vmin=np.amin(lz), vmax=np.amax(lz))
# plt.plot(x,y,markersize=5,color=cm.jet(lz))
#図の書式設定
plt.tick_params(which='major',width = 1, length = 10)
plt.tick_params(which='minor',width = 1, length = 5)
ax1.spines['top'].set_linewidth(3)
ax1.spines['bottom'].set_linewidth(3)
ax1.spines['left'].set_linewidth(3)
ax1.spines['right'].set_linewidth(3)
plt.xlabel(r"$x$",color='k', size=30)
plt.ylabel(r"$y$",color='k', size=30)
plt.xticks(color='k', size=25)
plt.yticks(color='k', size=25)
#図の凡例の有無や位置，サイズを調整
plt.legend(ncol=1, loc=4, borderaxespad=0, fontsize=25,frameon=False)
plt.colorbar()
#各グラフのアスペクト比を1:1にする
#################################
#図のマージン設定
plt.subplots_adjust(wspace=0.3, hspace=0.25)

#各自ファイルのパスを変えること．
plt.savefig('C:/Users/ikedah/Documents/tau{}om{}.png'.format(tau,mg))
#plt.savefig(r'C:/Users/ikedah/Downloads/2022-simulation-training-main/2022-simulation-training-main/report1-2-0.1-2-10.pdf')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
