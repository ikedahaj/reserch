# %%
# %matplotlib inline
import math
import matplotlib
# %config InlineBackend.figure_format = 'retina'
import matplotlib.cm as cm  # colormap
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as mpatches

plt.rcParams["text.usetex"] =False
plt.rcParams["font.size"] = 30

from matplotlib.collections import PatchCollection
from matplotlib.patches import Circle

resolution = 100 # the number of vertices
Np=70
L=10#28.3921935#33.93323376
tau=100.
d=1.
temp=[0.200,0.400,0.600,1.000]
max=2
patches = [[] for i in range(max-1)]  #空の二重配列を定義

fig = plt.figure(figsize=(24,12))

for j in range(1,max):
    
    
    ax = fig.add_subplot(1,1,1)
    t,x, y,vx,a = np.loadtxt("/Users/ikedahajime/GitHub/reserch-1/twocir/stwR10.0_coorlo0.20tau60.000m0.000bit1.300v01.0/tyouwaenn_lo0.200_tau60.000_m0.000_t-1.dat", comments='#', unpack=True)
    for i in range(Np):
        a[i]=1
        circle = mpatches.Ellipse((x[i],y[i]), a[i], a[i])
        patches[j-1].append(circle)
    bit=L+1.3*L/2
    # plt.xlim(-bit,bit)
    # plt.ylim(-L, L) 
    def circleplot():
        t = np.linspace(0,np.pi*2,1000)
        x = L * (np.cos(t))+bit-L
        y = L * np.sin(t)
        plt.plot(x,y,"-",color="k",markersize=20)
        x=-x
        plt.plot(x,y,"-",color="k",markersize=20)  
    circleplot()
    colors = a
    p = PatchCollection(patches[j-1], cmap=matplotlib.cm.jet, alpha=1.0,ec='k')
    p.set_array(colors)
    p.set_clim(0.8,1.2)
    ax.add_collection(p)
    ax.spines['top'].set_linewidth(3)
    ax.spines['bottom'].set_linewidth(3)
    ax.spines['left'].set_linewidth(3)
    ax.spines['right'].set_linewidth(3)
    plt.tick_params(which='major',width = 1, length = 10)
    plt.tick_params(which='minor',width = 1, length = 5)
    plt.plot([],[])
 
    plt.xlabel(r"$x/a$",color='k', size=35)
    plt.ylabel(r"$y/a$",color='k', size=35)
    
    plt.legend(title="t={}".format(t[j]),ncol=1, loc=4, borderaxespad=0, fontsize=20)
    plt.subplots_adjust(wspace=0.2, hspace=0.25)
    # plt.savefig('C:/Users/ikedah/Documents/sotukenn/maps/ouou_tau100{:d}.png'.format(j-1),bbox_inches="tight")
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# %matplotlib inline
import math
import matplotlib
# %config InlineBackend.figure_format = 'retina'
import matplotlib.cm as cm  # colormap
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as mpatches


##円教会用
plt.rcParams["text.usetex"] =False
plt.rcParams["font.size"] = 30
#from matplotlib import patches
from matplotlib.collections import PatchCollection
#from matplotlib.patches import Circle

resolution = 100 # the number of vertices
Np=750#2048#
L=70.7#22.627#33.93323376#100#143#28.3921935#40#
tau=10#100.
d=1#1.
min=2#1kara
max=3#最大－2
patches = [[] for i in range(max-1)]  #空の二重配列を定義
iti=["coor","anime"]
ni=[1,0]
fig = plt.figure(figsize=(12,12))

def circleplot(R):
    t = np.linspace(0,np.pi*2,1000)
    x = R * np.cos(t)
    y = R * np.sin(t)
    plt.plot(x,y,"-",color="k",markersize=20)
vminmax=3
for j in range(min,max):
    
    
    ax = fig.add_subplot(1,1,1)
    ax.set_aspect('equal')
    # t,x, y,vx,vy,xt,yt,a,a1,a2 = np.loadtxt("C:/Users/ikedah/Documents/sotukenn/workspace/manyaoup/pe80fai1.2/ljmaoup_T100.000_tau7.111_t{}.dat".format(j-1), comments='#', unpack=True)
    mgnta="0171"
    x, y,vx,vy= np.loadtxt("/Users/ikedahajime/GitHub/reserch-1/CABP/rstst/stwr20_5_coorlo0.50tau10.000m0.000v01.0/tyouwaenn_lo0.500_tau10.000_m0.000_t{}.dat".format(j), comments='#', unpack=True)
    lz=vx*y-vy*x/(x*x+y*y)
    a=np.ones_like(x)
    for i in range(0,Np):
        circle = mpatches.Ellipse((x[i],y[i]), a[i], a[i])
        patches[j-1].append(circle)
    
    # plt.xlim(-L, L)
    # plt.ylim(-L, L)    
    colors = lz
    p = PatchCollection(patches[j-1], cmap=matplotlib.cm.bwr, alpha=1.0,ec='k')
    p.set_array(colors)
    #
    
    p.set_clim(vmin=-vminmax, vmax=vminmax)
    circleplot(20)
    circleplot(5)
    ax.add_collection(p)
    ax.spines['top'].set_linewidth(3)
    ax.spines['bottom'].set_linewidth(3)
    ax.spines['left'].set_linewidth(3)
    ax.spines['right'].set_linewidth(3)
    plt.tick_params(which='major',width = 1, length = 10)
    plt.tick_params(which='minor',width = 1, length = 5)
    # plt.plot([],[],label="t={}".format(t[1]))
    cbar = plt.colorbar(p,label=r"$v_{\theta}$")
    plt.xlabel(r"$x$",color='k', size=35)
    plt.ylabel(r"$y$",color='k', size=35)
    
    # plt.legend(ncol=1, loc=4, borderaxespad=0, fontsize=20)
    plt.subplots_adjust(wspace=0.2, hspace=0.25)
    # plt.savefig('C:/Users/ikedah/Documents/sotukenn/maps/{}.png'.format(mgnta),bbox_inches="tight")
    plt.show()

# %%
# %matplotlib inline
import math
import matplotlib
# %config InlineBackend.figure_format = 'retina'
import matplotlib.cm as cm  # colormap
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as mpatches
##円教会用
plt.rcParams["text.usetex"] =True
plt.rcParams["font.size"] = 30
#from matplotlib import patches
from matplotlib.collections import EllipseCollection
from matplotlib.patches import Circle
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable, get_cmap

cmap = get_cmap('jet')

resolution = 100 # the number of vertices
Np=1024#2048#
L=160#22.627#33.93323376#100#143#28.3921935#40#
tau=7.111#100.
d=100#1.
temp=[0.200,0.400,0.600,1.000]
min=1#1kara
max=2#最大－2
patches = [[] for i in range(max-1)]  #空の二重配列を定義

fig = plt.figure(figsize=(12,12))
circl=[[]for i in range(Np)]
def circleplot():
    t = np.linspace(0,np.pi*2,50)
    x = L * np.cos(t)
    y = L * np.sin(t)
    plt.plot(x,y,"-",color="k",markersize=20)
ax = fig.add_subplot(1,1,1)
# circleplot()
# for j in range(min,max):
    
t,x, y,vx,a,lz = np.loadtxt("C:\\Users\\ikedah\\Documents\\sotukenn\\workspace\\atcoder\\tyouwaenn_R160.000_tau10.000_k0.000_m0.000_t{}.dat".format(j), comments='#', unpack=True)
cirs=EllipseCollection(1,1,0,offsets=np.c_[x,y],ec="k",cmap=cm.jet)

#カラーバーを出すために適当なマップをダス;
norm = Normalize(vmin=-3.5, vmax=3.5)
mappable = ScalarMappable(cmap=cmap, norm=norm)
mappable._A = []

# plt.xlim(-L, L)
# plt.ylim(-L, L)  

# colors = a
# p = PatchCollection(patches[j-1], cmap=matplotlib.cm.jet, alpha=1.0,ec='k')
# p.set_array(colors)
# p.set_clim(0.8,1.2)
# 
ax.add_collection(cirs)
cbar = plt.colorbar(mappable)

ax.spines['top'].set_linewidth(3)
ax.spines['bottom'].set_linewidth(3)
ax.spines['left'].set_linewidth(3)
ax.spines['right'].set_linewidth(3)
plt.tick_params(which='major',width = 1, length = 10)
plt.tick_params(which='minor',width = 1, length = 5)


plt.xlabel(r"$x/a$",color='k', size=35)
plt.ylabel(r"$y/a$",color='k', size=35)


plt.subplots_adjust(wspace=0.2, hspace=0.25)
for j in range(2):
    t,x, y,vx,a,lz = np.loadtxt("C:\\Users\\ikedah\\Documents\\sotukenn\\workspace\\atcoder\\tyouwaenn_R160.000_tau10.000_k0.000_m0.000_t{}.dat".format(j), comments='#', unpack=True)
    lz=lz/np.sqrt(np.square(x)+np.square(y))

    cirs.set_offsets(np.c_[x,y])
    cirs.set_array(lz)
    # plt.plot(L,L,label="t={}".format(t[1]),color="w")
    plt.legend(ncol=1, loc=4, borderaxespad=0, fontsize=20)
    plt.savefig('C:/Users/ikedah/Documents/sotukenn/maps/iiia0.01{:d}.png'.format(j),bbox_inches="tight")
plt.show()
# Out:
# C:\Users\ikedah\AppData\Local\Temp\ipykernel_4344\4252049316.py:58: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(mappable)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# %matplotlib inline
import math
import matplotlib
# %config InlineBackend.figure_format = 'retina'
import matplotlib.cm as cm  # colormap
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as mpatches

# plt.rcParams["text.usetex"] =True
plt.rcParams["font.size"] = 30
#from matplotlib import patches
from matplotlib.collections import PatchCollection
from matplotlib.patches import Circle
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable, get_cmap
cmap = matplotlib.colormaps["Greys"]
Np=2560#2048#
moji="stww"
tau=50#100.
v0=1
Mg=0.
lo=0.1
L=np.sqrt(Np/4/lo)
min=1
max=2
fig = plt.figure(figsize=(12,12))
ax = fig.add_subplot(1,1,1)
ax.set_aspect("equal")
L=80
def circleplot():
    t = np.linspace(0,np.pi*2,100)
    x = L * np.cos(t)
    y = L * np.sin(t)
    plt.plot(x,y,"-",color="k",markersize=20)
patches=[]



title=plt.title("t")
circleplot()
t,x, y,vx,vy = np.loadtxt("/Users/ikedahajime/simulation/anime/{}_animelo{:.2f}v0{:.1f}tau{:.3f}m{:.3f}/tyouwaenn_lo{:.3f}_tau{:.3f}_m{:.3f}_t{:n}.dat".format(moji,lo,v0,tau,Mg,lo,tau,Mg,100), comments='#', unpack=True)
lz=(x*vy-y*vx)/np.sqrt(np.square(x)+np.square(y))
vminmax=np.amax(np.abs(lz))

# k=np.concatenate([x, y])
for i in range(Np):
    cir=Circle((x[i],y[i]),0.5)
    patches.append(cir)

p = PatchCollection(patches, cmap=matplotlib.cm.jet, alpha=1.0,fc='k',ec=cmap(0.5))
# p.set_offsets(np.c_[x,y])
p.set_clim(vmin=-vminmax, vmax=vminmax) 
ax.add_collection(p)
p.set_array(lz)
C=plt.colorbar(p,label=r"$v_{\theta}$")
plt.xlim(-L, L)
plt.ylim(-L, L)  
ax.spines['top'].set_linewidth(3)
ax.spines['bottom'].set_linewidth(3)
ax.spines['left'].set_linewidth(3)
ax.spines['right'].set_linewidth(3)
plt.tick_params(which='major',width = 1, length = 10)
plt.tick_params(which='minor',width = 1, length = 5)
plt.xlabel(r"$x/a$",color='k', size=35)
plt.ylabel(r"$y/a$",color='k', size=35)
# plt.show()
for j in range(min,max):
    t,x, y,vx,a = np.loadtxt("/Users/ikedahajime/simulation/anime/{}_animelo{:.2f}v0{:.1f}tau{:.3f}m{:.3f}/tyouwaenn_lo{:.3f}_tau{:.3f}_m{:.3f}_t{:n}.dat".format(moji,lo,v0,tau,Mg,lo,tau,Mg,100), comments='#', unpack=True)
    lz=lz/np.sqrt(np.square(x)+np.square(y))
    # patches=[]
    """for i in range(Np):
        a[i]=0.5
        circle = mpatches.Circle((x[i],y[i]), a[i])
        patches.append(circle)
    p.set_paths(patches)"""
    p.set_offsets(np.c_[x, y])
    # p.set_sizes(a,1000)
    p.set_array(lz)
    title.set_text("t={}".format(t[0]))
    # plt.savefig('C:/Users/ikedah/Documents/sotukenn/maps/0.01{:d}.png'.format(j),bbox_inches="tight")
plt.show()

# %%
# %matplotlib inline
import math
import matplotlib
# %config InlineBackend.figure_format = 'retina'
import matplotlib.cm as cm  # colormap
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as mpatches

# plt.rcParams["text.usetex"] =True
plt.rcParams["font.size"] = 30
#from matplotlib import patches
from matplotlib.collections import EllipseCollection
from matplotlib.patches import Circle
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable, get_cmap
cmap = get_cmap('jet')
Np=4#2048#
moji="stww"
tau=50#100.
v0=1
Mg=0
lo=0.01
L=1#np.sqrt(Np/4/lo)
min=1
max=2
fig = plt.figure(figsize=(12,12))
ax = fig.add_subplot(1,1,1)
ax.set_aspect("equal")
def circleplot():
    t = np.linspace(0,np.pi*2,100)
    x = L * np.cos(t)
    y = L * np.sin(t)
    plt.plot(x,y,"-",color="k",markersize=20)
patches=[]



title=plt.title("t")
circleplot()
t,x, y,vx,a = np.loadtxt("/Users/ikedahajime/simulation/anime/{}_animelo{:.2f}v0{:.1f}tau{:.3f}m{:.3f}/tyouwaenn_lo{:.3f}_tau{:.3f}_m{:.3f}_t{:n}.dat".format(moji,lo,v0,tau,Mg,lo,tau,Mg,0), comments='#', unpack=True)
# lz=lz/np.sqrt(np.square(x)+np.square(y))
# vminmax=np.amax(np.abs(lz))
# p.set_clim(vmin=-vminmax, vmax=vminmax) 
# k=np.concatenate([x, y])
a=np.empty_like([0])
a.fill(1)#粒径
p = EllipseCollection(a,a,a,transOffset=ax.transData, cmap=matplotlib.cm.bwr, alpha=1.0)
p.set_offsets((0,0))#np.c_[x,y])
ax.add_collection(p)
# p.set_array(lz)
# C=plt.colorbar(p,label=r"$v_{\theta}$")
# plt.xlim(-L, L)
# plt.ylim(-L, L)  
ax.spines['top'].set_linewidth(3)
ax.spines['bottom'].set_linewidth(3)
ax.spines['left'].set_linewidth(3)
ax.spines['right'].set_linewidth(3)
plt.tick_params(which='major',width = 1, length = 10)
plt.tick_params(which='minor',width = 1, length = 5)
plt.xlabel(r"$x/a$",color='k', size=35)
plt.ylabel(r"$y/a$",color='k', size=35)
for j in range(min,max):
    # t,x, y,vx,a = np.loadtxt("/Users/ikedahajime/simulation/atcoder/{}_animelo{:.2f}v0{:.1f}tau{:.3f}m{:.3f}/tyouwaenn_lo{:.3f}_tau{:.3f}_m{:.3f}_t{:n}.dat".format(moji,lo,v0,tau,Mg,lo,tau,Mg,0), comments='#', unpack=True)
    # lz=lz/np.sqrt(np.square(x)+np.square(y))
    # patches=[]
    """for i in range(Np):
        a[i]=0.5
        circle = mpatches.Circle((x[i],y[i]), a[i])
        patches.append(circle)
    p.set_paths(patches)"""
    # p.set_offsets(np.c_[x, y])
    # p.set_sizes(a,1000)
    # p.set_array(lz)
    title.set_text("t={}".format(t[0]))
    # plt.savefig('C:/Users/ikedah/Documents/sotukenn/maps/0.01{:d}.png'.format(j),bbox_inches="tight")
    plt.show()
# Out:
# /var/folders/b6/n9yx9yhx6rg4r08q6mdm1r1m0000gn/T/ipykernel_45050/394762255.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = get_cmap('jet')
